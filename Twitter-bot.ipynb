# %%
import os
import yaml as _yaml
import logging
import tweepy

# %%
API_key = "yOFrLYJZ9hyTJtQT3NxbT2yUK" #APIkey
API_secret_key = "0RbjOnqEBnMbKjGfgDYeWulqBhipShe35i4q3S55Nq2J5TBvIF"#Apisecrectkey
access_token="1064994930404274178-DbqZy5BwUJCshvLuuSFaYE7GHpiYbA"
access_token_secret = "68k5WeFwKBzCm2dsnVodR3Z1JTEC1wnugDCWOph1hwh6o"

# %%
auth= tweepy.OAuthHandler (API_key, API_secret_key) 
auth.set_access_token (access_token, access_token_secret)

# %%
api = tweepy.API(auth, wait_on_rate_limit=True,
    wait_on_rate_limit_notify=True)

# %%
import json

# %%
class MyStreamListener(tweepy.StreamListener):
    def __init__(self, api):
        self.api = api
        self.me = api.me()

    def on_status(self, tweet):
        print(f"{tweet.user.name}:{tweet.text}")

    def on_error(self, status):
        print("Error detected")

# %%
tweets_listener = MyStreamListener(api)
stream = tweepy.Stream(api.auth, tweets_listener)
stream.filter(track=["#Trump"], languages=["en"])
# Out:
# HealthyGardenDiva:...because you cannot #trump good health🤗 #healthy choices #healthyme #eatmoreveggies
# Mike 🏳️‍🌈 🇬🇧 🏳️‍🌈:RT @gray_mgray70: How are the left dealing with this after putting extreme Muslims &amp; gays under the same collective umbrella?
# Pure silence,…
# Melo:RT @RichardAngwin: Trump's stupidity has brought us to the brink of war with Iran. Unreal.
#
# #SundayThoughts #Resist #Trump #1u #tcot #maga…
# (ツ)Vendetta:🚨 LEARN WHY #TRUMP HAD TO STRIKE!
#
# 🔴 https://t.co/AmowkVJ38X
#
# #AlexJones #AlexJonesShow #Infowars… https://t.co/1ghMzQyEho
# anna martin:RT @PatriotBluesT: #Iran was use to their “ brother in arms” aka #Obama for quick cash to help fund their dirty deeds and killing the innoc…
# S. Ali Shah:RT @BandeKhuda: Stupid decision by #Trump has moved "DEATH TO AMERICA"  to Iraq, Turkey, Yemen, Pakistan, Kashmir, Palestine and inshaAllah…
# ...

# %%
for tweet in tweepy.Cursor(api.home_timeline).items(100):
    print(f"{tweet.user.name} said: {tweet.text}")
# Out:
# AM Querétaro said: #AMQuerétaro  🗞 | Los ciudadanos de El Marqués podrán realizar el pago de su impuesto predial con descuentos de 20… https://t.co/ekVOsjZjVz
# Aristegui Noticias said: No hay forma de escapar al dolor. Negarlo, sostiene el escritor italiano, equivale a renegar de una parte de nuestr… https://t.co/k5Zz3w2yNe
# AM Querétaro said: #VideoPortada 🎥 ✨ |  Recursos federales crecen para la entidad
#
# https://t.co/ctzG5h5aWH https://t.co/l5jonEErW3
# AM Querétaro said: #DíaDeReyes 👑 | Personas discapacitadas en Querétaro elaborarán roscas de reyes este fin de semana con la ayuda de… https://t.co/1dXZNkLjFP
# Aristegui Noticias said: Esta ley obliga al gobierno local de Bagdad a expulsar a las tropas que trabajan en coalición y dirigidos por EE.UU. https://t.co/YPYRjHLbpK
# Aristegui Noticias said: #PrimerosCapítulos | El Colegio de Sonora publica un estudio acerca del impacto de la violencia en la democracia… https://t.co/9zCR4llDxY
# ...
